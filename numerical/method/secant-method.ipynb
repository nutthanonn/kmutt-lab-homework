# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x): return x**3 - 5*x + 1

def secant(x0, x1):

    # ในกรณีที่ไม่มีจุดตัดหรือหาค่าจุดตัดไม่ได้ มันต้องมี tol เพื่อที่จะ break การทำงานของ while loop นี้
    while np.sign(f(x0) - f(x1)) != 0:
        x = x1 - (( x0 - x1) / (f(x0) - f(x1)))*f(x1)
        print(x)
        x0 = x1
        x1 = x
        
secant(0, 1)
# Out:
# 0.25
# 0.1864406779661017
# 0.20173625617912722
# 0.2016398528913041
# 0.20163967572128236
# 0.2016396757234047
# 0.20163967572340463
# 0.20163967572340466

# %%
x_plot = np.linspace(0, 3, 1000)

y_plot = f(x_plot)
fig = plt.figure()
plt.plot(x_plot, y_plot, c='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()
